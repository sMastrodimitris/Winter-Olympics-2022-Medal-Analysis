# %%
import requests
from bs4 import BeautifulSoup
import csv

def crawl(url):
    response = requests.get(url)

    if response.status_code == 200:
        print(response.text)  # Print the page content to inspect its structure
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table', class_='wikitable')

        if table:
            rows = table.find_all('tr')
            data = []

            for row in rows[1:]:
                cells = row.find_all(['th', 'td'])
                if len(cells) >= 3:
                    country = cells[1].text.strip()
                    urbanization = cells[3].text.strip()
                    data.append((country, urbanization))

            return data
        else:
            print("Table not found on the page.")
            return None
    else:
        print(f"Failed to fetch the page. Status code: {response.status_code}")
        return None
    
url = "https://en.wikipedia.org/wiki/Urbanization_by_sovereign_state"
result = crawl(url)

if result:
    for country, urbanization in result:
        print(f"{country}: {urbanization}")
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Urbanization by sovereign state - Wikipedia</title>
# ...

# %%
def crawl_urbanization(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table', class_='wikitable')

        if table:
            rows = table.find_all('tr')
            data = []

            for row in rows[1:]:
                cells = row.find_all(['td', 'th'])

                # Check if there are at least 4 cells in the row
                if len(cells) >= 4:
                    country = cells[1].find('a').text.strip()
                    urbanization = cells[2].text.strip()
                    data.append((country, urbanization))

            return data
        else:
            print("Table not found on the page.")
            return None
    else:
        print(f"Failed to fetch the page. Status code: {response.status_code}")
        return None

url = "https://en.wikipedia.org/wiki/Urbanization_by_sovereign_state"
result = crawl_urbanization(url)

if result:
    for country, urbanization in result:
        print(f"{country}: {urbanization}")
# Out:
# Kuwait: 100
# Monaco: 100
# Nauru: 100
# Singapore: 100
# Vatican City: 100
# Anguilla: 100
# Bermuda: 100
# Cayman Islands: 100
# Gibraltar: 100
# Hong Kong: 100
# Macau: 100
# Sint Maarten: 100
# Qatar: 99.2
# Belgium: 98.1
# San Marino: 97.5
# U.S. Virgin Islands: 95.9
# Uruguay: 95.5
# Guam: 94.9
# Malta: 94.7
# Iceland: 93.9
# Puerto Rico: 93.6
# Turks and Caicos Islands: 93.6
# Israel: 92.6
# Netherlands: 92.2
# Argentina: 92.1
# Northern Mariana Islands: 91.8
# Japan: 91.8
# Luxembourg: 91.5
# Jordan: 91.4
# Saint Pierre and Miquelon: 90
# Gabon: 90.1
# Bahrain: 89.5
# Curaçao: 89.1
# Lebanon: 88.9
# Venezuela: 88.3
# Denmark: 88.1
# Sweden: 88
# Andorra: 87.9
# Chile: 87.7
# American Samoa: 87.2
# Greenland: 87.3
# Western Sahara: 86.8
# Brazil: 87.1
# United Arab Emirates: 87
# New Zealand: 86.7
# Oman: 86.3
# Australia: 86.2
# Finland: 85.5
# Saudi Arabia: 84.3
# United Kingdom: 83.9
# Bahamas: 83.2
# Norway: 83
# United States: 82.7
# Dominican Republic: 82.5
# ...

# %%
csv_file = "R_urbanisation.csv"
with open(csv_file, mode='w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Country', 'Urbanization (%)'])
    writer.writerows(result)
