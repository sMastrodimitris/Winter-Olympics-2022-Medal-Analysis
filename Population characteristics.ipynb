# %%
import requests
from bs4 import BeautifulSoup

def crawl(url):
    response = requests.get(url)

    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch the page. Status code: {response.status_code}")
        return None

url = "https://www.worlddata.info/average-bodyheight.php"
html_content = crawl(url)

if html_content:
    soup = BeautifulSoup(html_content, 'html.parser')
    pretty_html = soup.prettify()
    print(pretty_html)
else:
    print("Failed to fetch the page.")
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Average height for men and women worldwide
#   </title>
#   <link href="https://js.worlddata.info" rel="preconnect"/>
#   <link href="https://js.worlddata.info" rel="dns-prefetch"/>
#   <link href="https://cdn.worlddata.info" rel="preconnect"/>
#   <link href="https://cdn.worlddata.info" rel="dns-prefetch"/>
#   <link href="https://www.laenderdaten.info/durchschnittliche-koerpergroessen.php" hreflang="de" rel="alternate"/>
#   <link href="https://www.worlddata.info/average-bodyheight.php" hreflang="en" rel="alternate"/>
#   <link href="https://www.datosmundial.com/estatura-promedio.php" hreflang="es" rel="alternate"/>
#   <link href="https://www.dadosmundiais.com/altura-media.php" hreflang="pt" rel="alternate"/>
#   <link href="https://www.donneesmondiales.com/taille-moyenne.php" hreflang="fr" rel="alternate"/>
#   <link href="https://www.worlddata.info/average-bodyheight.php" id="canonical" rel="canonical"/>
#   <meta content="How tall is a human? Height and weight for men and women in an international comparison" name="description"/>
#   <meta content="index,follow,max-image-preview:large" name="robots"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="360" name="MobileOptimized"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1,user-scalable=yes" name="viewport"/>
#   <meta content="#00405D" media="(prefers-color-scheme:light)" name="theme-color"/>
#   <meta content="#000000" media="(prefers-color-scheme:dark)" name="theme-color"/>
#   <link href="//cdn.worlddata.info/pics/favs/64x64.png" rel="icon" sizes="16x16 24x24 32x32 48x48 64x64" type="image/png"/>
#   <link href="//cdn.worlddata.info/pics/favs/192x192.png" rel="apple-touch-icon" sizes="72x72 76x76 114x114 120x120 144x144 152x152 180x180 192x192"/>
#   <link href="//cdn.worlddata.info/pics/favs/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#   <link href="//cdn.worlddata.info/css/footer7-en.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <meta content="Average height for men and women worldwide" property="og:title"/>
#   <meta content="How tall is a human? Height and weight for men and women in an international comparison" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.worlddata.info/average-bodyheight.php" property="og:url"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="Worlddata.info" property="og:site_name"/>
#   <meta content="https://cdn.worlddata.info/pics/og/crowds3.jpg" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="628" property="og:image:height"/>
#   <meta content="https://cdn.worlddata.info/pics/og/crowds3.jpg" name="twitter:image"/>
#   <meta content="Average height for men and women worldwide" name="twitter:title"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="How tall is a human? Height and weight for men and women in an international comparison" name="twitter:description"/>
#   <script defer="" src="//js.worlddata.info/public13-en.js">
#   </script>
#   <style>
#    html,body{background-color:#DBD7D0;margin:0;font-size:9pt;color:#000;font-family:Verdana,Arial,Helvetica,Roboto;line-height:135%}#outer-wrap{max-width:990px;margin:0 auto;box-shadow:0 0 30px 5px rgba(0,0,0,.3);background-color:#fff}header{padding:80px 0 0 0;background-image:linear-gradient(to bottom,#fff 25%,#e2e2e2)}#navbar{height:13px}#sitetitle{float:left;width:300px;height:35px;text-align:left;padding-left:10px;margin-top:-5px}#topnav a,abbr{text-decoration:none !important}img,table{border:0}#intro1{position:relative;overflow:hidden;height:auto;box-sizing:border-box;color:#fff;padding:0}#intro3{position:relative;background-color:rgba(0,70,99,.75);padding:4% 4% 30px 4%;text-align:left;box-sizing:border-box}#intro1 a{color:#0ff}#blurbg{position:absolute;top:-20px;left:-20px;right:-20px;bottom:-20px;overflow:hidden;background-repeat:no-repeat;background-position:center center;background-size:cover;filter:blur(3px)}#blurbg.satellite{filter:blur(0px)}#intro3.satellite{background-color:rgba(0,40,40,.7)}.boxwhite{background-color:#fff;padding:30px}.greybg{background-color:#eee}.clear{clear:both}.br3{height:3em}.large{font-size:2em;margin:20px 0}a.langh{padding-left:22px}.center,tr.center th,tr.center td,div.map{text-align:center}.left,tr.left th:not(.right),tr.left td:not(.right){text-align:left !important}.right,tr.right th:not(.left),tr.right td:not(.left){text-align:right}.top,tr.top th:not(.bottom),tr.top td:not(.bottom){vertical-align:top}.bottom,tr.bottom th:not(.top),tr.bottom td:not(.top){vertical-align:bottom}img.right{float:right}img.deko{display:none;max-width:340px;height:auto;float:left;box-shadow:3px 3px 6px #000;margin:0 50px 30px 0}.floater{overflow:hidden}a{color:#3B45BA}h1{font-size:25pt;margin-top:0px;font-weight:normal;line-height:30pt;text-shadow:2px 2px 3px rgba(0,0,0,.5)}h2,.h2{font-size:16pt;color:#0D1656;line-height:160%;font-weight:normal}h3,.h3{font-size:13pt;color:#0D1656;line-height:140%;font-weight:normal;margin-bottom:10px}.nowrap{white-space:nowrap}img.shadow{box-shadow:3px 3px 6px #000}img.graph,picture.graph{max-width:100%;height:auto;margin:0 auto}br.br2,br.br3{display:block;margin-bottom:1em;content:' '}br.br3{margin-bottom:2em}a.btn,input.btn,button.btn{background-color:#666;color:#fff !important;padding:3px 20px 3px 20px;border:0px;border-radius:9px;cursor:pointer;text-align:center;text-decoration:none;white-space:nowrap}#intro1 .btn{background-color:#fff;color:#3B45BA !important}.boxwhite .btn{color:#3B45BA;font-weight:bold}.adtg{min-height:3px;text-align:center}#vidad{min-height:250px}div.hrz,div.bbd{display:block;width:auto;min-width:728px;min-height:90px;margin:5px auto 10px auto}div.bbd{min-width:970px;min-height:325px;margin:0}.cad,.cad-right{display:block;min-width:300px}ins.adsbygoogle{display:block;margin:0 auto}#searchform form{display:block;width:auto;padding:1px 1px 0 2px;border:1px solid #02968C;background-color:#fff;border-radius:5px;float:right}#searchform input[type=text]{width:185px;height:20px;font-size:13px;outline:none;border:0;background-color:transparent;color:#000}#searchgo{border:0;background-color:transparent;height:21px;width:21px;vertical-align:middle;margin:0 0 2px 15px}#menubtn{font-size:34px;color:#000;margin-right:10px;float:right;width:auto;display:inline-block}@media (max-width:630px){html,body{font-size:11pt}table.std100 tr>*{font-size:10pt}header{display:block;position:fixed;top:0;left:0;right:0;height:23px;padding:16px 12px;z-index:998;background-image:linear-gradient(to bottom,#fff,#e2e2e2);transition:all .5s ease-in-out}#sitetitle{width:240px;height:28px;padding-left:7px;margin-bottom:5px}#searchform form{width:240px;margin:15px auto;float:none;background-color:#D7DCDF}#searchform{border-bottom:1px solid #60A0BD;padding-bottom:15px}#inner-wrap{margin-top:55px}.ab630,#navbar{display:none}.sidenav{display:block;position:fixed;top:0;bottom:0;left:100%;width:250px;padding:10px;background-color:#ddd;z-index:999;overflow-y:auto}.nav-out{transform:translateX( ...
#   </style>
#  </head>
#  <body data-page="Rankings:Körpergröße">
#   <div id="outer-wrap">
#    <div id="inner-wrap">
#     <header>
#      <nav id="menubtn" onclick="toggleNav('topnav');">
#       ☰
#      </nav>
#      <div id="searchcombo">
#      </div>
#      <a href="/">
#       <img alt="Worlddata.info" height="35" id="sitetitle" src="//cdn.worlddata.info/pics/logo-en750.png" width="300"/>
#      </a>
#      <nav class="sidenav nav-out" data-navbardefault="0" id="topnav">
#       <div class="subtitle">
#        <b id="navclose" onclick="toggleNav('topnav');">
#         ✕
#        </b>
#        Countries in...
#       </div>
#       <a class="am" data-navbar="585" href="/america/index.php">
#        Americas
#       </a>
#       <a class="eu" data-navbar="500" href="/europe/index.php">
#        Europe
#       </a>
#       <a class="as" data-navbar="421" href="/asia/index.php">
#        Asia
#       </a>
#       <a class="af" data-navbar="349" href="/africa/index.php">
#        Africa
#       </a>
#       <a class="au" data-navbar="260" href="/australia/index.php">
#        Australia
#       </a>
#       <a class="oz" data-navbar="155" href="/oceania/index.php">
#        Oceania
#       </a>
#       <div class="no-desktop">
#        <div class="subtitle">
#         Geography
#        </div>
#        <a href="/the-largest-countries.php">
#         Largest countries
#        </a>
#        <a href="/highest-mountains.php">
#         Highest mountains
#        </a>
#        <a href="/capital-cities.php">
#         Capital cities
#        </a>
#        <a href="/megacities.php">
#         Megacities
#        </a>
#        <a href="/biggest-airports.php">
#         Biggest airports
#        </a>
#        <a href="/timezones/index.php">
#         Timezones
#        </a>
#        <div class="subtitle">
#         Population
#        </div>
#        <a href="/populationgrowth.php">
#         Population growth
#        </a>
#        <a href="/population-density.php">
#         Population density
#        </a>
#        <a href="/average-bodyheight.php">
#         Average body heights
#        </a>
#        <a href="/life-expectancy.php">
#         Life expectancy
#        </a>
#        <a href="/iq-by-country.php">
#         IQ by country
#        </a>
#        <a href="/quality-of-life.php">
#         Quality of life
#        </a>
#        <a href="/languages/index.php">
#         Languages
#        </a>
#        <a href="/religions/index.php">
#         Religions
#        </a>
#        <a href="/refugees-by-country.php">
#         Refugees
#        </a>
#        <div class="subtitle">
#         Economy
#        </div>
#        <a href="/richest-countries.php">
#         Richest countries
#        </a>
#        <a href="/unemployment-rates.php">
#         Unemployment rates
#        </a>
#        <a href="/average-income.php">
#         Average income
#        </a>
#        <a href="/income-taxes.php">
#         Income taxes
#        </a>
#        <a href="/cost-of-living.php">
#         Cost of living
#        </a>
#        <a href="/tourism.php">
#         Top travel countries
#        </a>
#        <a href="/corruption.php">
#         Corruption
#        </a>
#        <a href="/tax-havens.php">
#         Tax havens
#        </a>
#        <a href="/currencies/">
#         Currencies
#        </a>
#        <div class="subtitle">
#         Climate + Nature
#        </div>
#        <a href="/earthquakes.php">
#         Earthquakes
#        </a>
#        <a href="/volcanoes.php">
#         Volcanoes
#        </a>
#        <a href="/cyclones.php">
#         Cyclones
#        </a>
#        <a href="/global-warming.php">
#         Global warming
#        </a>
#        <a href="/greenhouse-gas-by-country.php">
#         CO2 emissions
#        </a>
#       </div>
#      </nav>
#      <div class="clear" data-pos="0" id="navbar" style="background-position:0px 0px;">
#      </div>
#     </header>
#     <main id="main">
#      <div id="intro1">
#       <div id="blurbg" style="background-image:url(//cdn.worlddata.info/pics/crowds3.jpg);">
#       </div>
#       <div id="intro3">
#        <img alt="Population average" class="deko" height="320" src="//cdn.worlddata.info/pics/crowds3.jpg" width="320"/>
#        <div class="floater">
#         <h1>
#          Average height and weight by country
#         </h1>
#         The wealthier a country is, the taller are its residents — or so they claim. Yet for the traditional immigration countries like Hong Kong and Singapore, it is obviously wrong.
#         <p>
#          The tallest average height for a man is
#          <span class="metric">
#           1.84 m
#          </span>
#          in the Netherlands, the smallest women at just
#          <span class="metric">
#           1.51 m
#          </span>
#          can be found in Guatemala.
#          <p>
#           ▼
#           <a href="#by-country">
#            Heights by country
#           </a>
#           <br/>
#           ▼
#           <a href="#by-area">
#            Heights by continents
#           </a>
#           <br/>
#          </p>
#         </p>
#        </div>
#        <div class="clear">
#        </div>
#       </div>
#      </div>
#      <div id="metricToggler">
#       <a href="#" onclick="return toggleMetrics('us');">
#        Convert units to feet and pounds.
#       </a>
#      </div>
#      <div class="boxwhite">
#       <h2 id="by-country">
#        Average sizes of men and women
#       </h2>
#       The following table shows the average sizes, weights and BMI from 125 countries. All figures refer to men and women between the ages of 18 and 25 years. In the US, the average male is
#       <span class="metric">
#        1.77 m
#       </span>
#       tall. The average US-american woman reaches
#       <span class="metric">
#        14 cm
#       </span>
#       less with a height of
#       <span class="metric">
#        1.63 m
#       </span>
#       .
#      </div>
#      <div class="adtg bbd" data-gptfrmt="bbd" id="adtg-1">
#       <ins class="adsbygoogle" data-ad-client="ca-pub-0315193065476355" data-ad-format="horizontal" data-ad-slot="2913722277" data-full-width-responsive="true" id="ags1">
#       </ins>
#      </div>
#      <div class="boxwhite">
#       <div id="averageheights">
#        <h2>
#         Male
#        </h2>
#        <div class="tablescroller">
#         <table class="hover std100 lnwrap">
#          <tr>
#           <th class="left">
#            Country
#           </th>
#           <th class="right" colspan="3">
#            Average height / Weight / BMI
#           </th>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_NLD" href="/europe/netherlands/index.php">
#             Netherlands
#            </a>
#           </td>
#           <td>
#            1.84 m
#           </td>
#           <td>
#            87.9 kg
#           </td>
#           <td>
#            26.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_MNE" href="/europe/montenegro/index.php">
#             Montenegro
#            </a>
#           </td>
#           <td>
#            1.83 m
#           </td>
#           <td>
#            90.4 kg
#           </td>
#           <td>
#            27.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_EST" href="/europe/estonia/index.php">
#             Estonia
#            </a>
#           </td>
#           <td>
#            1.82 m
#           </td>
#           <td>
#            89.9 kg
#           </td>
#           <td>
#            27.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_DNK" href="/europe/denmark/index.php">
#             Denmark
#            </a>
#           </td>
#           <td>
#            1.82 m
#           </td>
#           <td>
#            86.8 kg
#           </td>
#           <td>
#            26.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_BIH" href="/europe/bosnia-and-herzegovina/index.php">
#             Bosnia and Herzegovina
#            </a>
#           </td>
#           <td>
#            1.82 m
#           </td>
#           <td>
#            87.1 kg
#           </td>
#           <td>
#            26.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_ISL" href="/europe/iceland/index.php">
#             Iceland
#            </a>
#           </td>
#           <td>
#            1.81 m
#           </td>
#           <td>
#            89.2 kg
#           </td>
#           <td>
#            27.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_CZE" href="/europe/czechia/index.php">
#             Czechia
#            </a>
#           </td>
#           <td>
#            1.81 m
#           </td>
#           <td>
#            91.9 kg
#           </td>
#           <td>
#            28.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_SVN" href="/europe/slovenia/index.php">
#             Slovenia
#            </a>
#           </td>
#           <td>
#            1.81 m
#           </td>
#           <td>
#            87.0 kg
#           </td>
#           <td>
#            26.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_SVK" href="/europe/slovakia/index.php">
#             Slovakia
#            </a>
#           </td>
#           <td>
#            1.81 m
#           </td>
#           <td>
#            89.5 kg
#           </td>
#           <td>
#            27.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_HRV" href="/europe/croatia/index.php">
#             Croatia
#            </a>
#           </td>
#           <td>
#            1.81 m
#           </td>
#           <td>
#            91.3 kg
#           </td>
#           <td>
#            28.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_SRB" href="/europe/serbia/index.php">
#             Serbia
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            86.9 kg
#           </td>
#           <td>
#            26.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_SWE" href="/europe/sweden/index.php">
#             Sweden
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            87.1 kg
#           </td>
#           <td>
#            26.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_NOR" href="/europe/norway/index.php">
#             Norway
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            89.1 kg
#           </td>
#           <td>
#            27.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_LTU" href="/europe/lithuania/index.php">
#             Lithuania
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            88.1 kg
#           </td>
#           <td>
#            27.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_POL" href="/europe/poland/index.php">
#             Poland
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            89.0 kg
#           </td>
#           <td>
#            27.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_UKR" href="/europe/ukraine/index.php">
#             Ukraine
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            87.6 kg
#           </td>
#           <td>
#            27.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_FIN" href="/europe/finland/index.php">
#             Finland
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            86.3 kg
#           </td>
#           <td>
#            26.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_LVA" href="/europe/latvia/index.php">
#             Latvia
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            87.9 kg
#           </td>
#           <td>
#            27.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_DEU" href="/europe/germany/index.php">
#             Germany
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            88.7 kg
#           </td>
#           <td>
#            27.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_DMA" href="/america/dominica/index.php">
#             Dominica
#            </a>
#           </td>
#           <td>
#            1.80 m
#           </td>
#           <td>
#            80.7 kg
#           </td>
#           <td>
#            25.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_BEL" href="/europe/belgium/index.php">
#             Belgium
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            85.9 kg
#           </td>
#           <td>
#            26.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_BMU" href="/america/bermuda/index.php">
#             Bermuda
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            88.4 kg
#           </td>
#           <td>
#            27.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_GRC" href="/europe/greece/index.php">
#             Greece
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            88.1 kg
#           </td>
#           <td>
#            27.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_PRI" href="/america/puerto-rico/index.php">
#             Puerto Rico
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            90.7 kg
#           </td>
#           <td>
#            28.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_CHE" href="/europe/switzerland/index.php">
#             Switzerland
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            85.5 kg
#           </td>
#           <td>
#            26.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_au fl_AUS" href="/australia/australia/index.php">
#             Australia
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            88.3 kg
#           </td>
#           <td>
#            27.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_IRL" href="/europe/ireland/index.php">
#             Ireland
#            </a>
#           </td>
#           <td>
#            1.79 m
#           </td>
#           <td>
#            89.2 kg
#           </td>
#           <td>
#            28.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_CAN" href="/america/canada/index.php">
#             Canada
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            87.3 kg
#           </td>
#           <td>
#            27.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_AUT" href="/europe/austria/index.php">
#             Austria
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            84.6 kg
#           </td>
#           <td>
#            26.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_FRA" href="/europe/france/index.php">
#             France
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            82.6 kg
#           </td>
#           <td>
#            26.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_ATG" href="/america/antigua-barbuda/index.php">
#             Antigua and Barbuda
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            81.6 kg
#           </td>
#           <td>
#            25.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_LBN" href="/asia/lebanon/index.php">
#             Lebanon
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            88.9 kg
#           </td>
#           <td>
#            28.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_BLR" href="/europe/belarus/index.php">
#             Belarus
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            84.1 kg
#           </td>
#           <td>
#            26.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_AND" href="/europe/andorra/index.php">
#             Andorra
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            87.3 kg
#           </td>
#           <td>
#            27.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_PYF" href="/oceania/french-polynesia/index.php">
#             French Polynesia
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            93.8 kg
#           </td>
#           <td>
#            29.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_COK" href="/oceania/cook-islands/index.php">
#             Cook Islands
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            103.7 kg
#           </td>
#           <td>
#            32.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_LUX" href="/europe/luxembourg/index.php">
#             Luxembourg
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            86.2 kg
#           </td>
#           <td>
#            27.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_GBR" href="/europe/united-kingdom/index.php">
#             United Kingdom
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            86.7 kg
#           </td>
#           <td>
#            27.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_GRD" href="/america/grenada/index.php">
#             Grenada
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            79.3 kg
#           </td>
#           <td>
#            25.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_au fl_NZL" href="/australia/new-zealand/index.php">
#             New Zealand
#            </a>
#           </td>
#           <td>
#            1.78 m
#           </td>
#           <td>
#            88.9 kg
#           </td>
#           <td>
#            28.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_ROU" href="/europe/romania/index.php">
#             Romania
#            </a>
#           </td>
#           <td>
#            1.77 m
#           </td>
#           <td>
#            85.1 kg
#           </td>
#           <td>
#            27.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_NIU" href="/oceania/niue/index.php">
#             Niue
#            </a>
#           </td>
#           <td>
#            1.77 m
#           </td>
#           <td>
#            98.8 kg
#           </td>
#           <td>
#            31.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_USA" href="/america/usa/index.php">
#             United States
#            </a>
#           </td>
#           <td>
#            1.77 m
#           </td>
#           <td>
#            90.6 kg
#           </td>
#           <td>
#            29.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_ASM" href="/oceania/american-samoa/index.php">
#             American Samoa
#            </a>
#           </td>
#           <td>
#            1.77 m
#           </td>
#           <td>
#            103.2 kg
#           </td>
#           <td>
#            33.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_HUN" href="/europe/hungary/index.php">
#             Hungary
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            87.6 kg
#           </td>
#           <td>
#            28.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_RUS" href="/europe/russia/index.php">
#             Russia
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            80.3 kg
#           </td>
#           <td>
#            25.9
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_TKL" href="/oceania/tokelau/index.php">
#             Tokelau
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            99.0 kg
#           </td>
#           <td>
#            32.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_LCA" href="/america/saint-lucia/index.php">
#             Saint Lucia
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            91.1 kg
#           </td>
#           <td>
#            29.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_ESP" href="/europe/spain/index.php">
#             Spain
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            84.0 kg
#           </td>
#           <td>
#            27.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_TUR" href="/asia/turkey/index.php">
#             Turkey
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            84.0 kg
#           </td>
#           <td>
#            27.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_ISR" href="/asia/israel/index.php">
#             Israel
#            </a>
#           </td>
#           <td>
#            1.76 m
#           </td>
#           <td>
#            85.4 kg
#           </td>
#           <td>
#            27.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_MAR" href="/africa/morocco/index.php">
#             Morocco
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            78.0 kg
#           </td>
#           <td>
#            25.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_BRA" href="/america/brazil/index.php">
#             Brazil
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            80.7 kg
#           </td>
#           <td>
#            26.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_GEO" href="/asia/georgia/index.php">
#             Georgia
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            84.2 kg
#           </td>
#           <td>
#            27.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_KOR" href="/asia/south-korea/index.php">
#             South Korea
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            74.7 kg
#           </td>
#           <td>
#            24.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_IRN" href="/asia/iran/index.php">
#             Iran
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            77.3 kg
#           </td>
#           <td>
#            25.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_TON" href="/oceania/tonga/index.php">
#             Tonga
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            93.7 kg
#           </td>
#           <td>
#            30.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_CHN" href="/asia/china/index.php">
#             China
#            </a>
#           </td>
#           <td>
#            1.75 m
#           </td>
#           <td>
#            73.5 kg
#           </td>
#           <td>
#            24.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_KAZ" href="/asia/kazakhstan/index.php">
#             Kazakhstan
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            80.0 kg
#           </td>
#           <td>
#            26.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_HKG" href="/asia/hong-kong/index.php">
#             Hong Kong
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            74.4 kg
#           </td>
#           <td>
#            24.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_ARG" href="/america/argentina/index.php">
#             Argentina
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            84.7 kg
#           </td>
#           <td>
#            27.9
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_ITA" href="/europe/italy/index.php">
#             Italy
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            80.9 kg
#           </td>
#           <td>
#            26.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_PRT" href="/europe/portugal/index.php">
#             Portugal
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            79.5 kg
#           </td>
#           <td>
#            26.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_PRK" href="/asia/north-korea/index.php">
#             North Korea
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            73.1 kg
#           </td>
#           <td>
#            24.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_DZA" href="/africa/algeria/index.php">
#             Algeria
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            74.6 kg
#           </td>
#           <td>
#            24.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_CRI" href="/america/costa-rica/index.php">
#             Costa Rica
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            80.9 kg
#           </td>
#           <td>
#            26.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_ALB" href="/europe/albania/index.php">
#             Albania
#            </a>
#           </td>
#           <td>
#            1.74 m
#           </td>
#           <td>
#            81.4 kg
#           </td>
#           <td>
#            27.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_WSM" href="/oceania/samoa/index.php">
#             Samoa
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            91.8 kg
#           </td>
#           <td>
#            30.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_ARE" href="/asia/arab-emirates/index.php">
#             United Arab Emirates
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            84.5 kg
#           </td>
#           <td>
#            28.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_eu fl_BGR" href="/europe/bulgaria/index.php">
#             Bulgaria
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            81.8 kg
#           </td>
#           <td>
#            27.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_TWN" href="/asia/taiwan/index.php">
#             Taiwan
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            75.0 kg
#           </td>
#           <td>
#            25.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_SGP" href="/asia/singapore/index.php">
#             Singapore
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            72.8 kg
#           </td>
#           <td>
#            24.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_IRQ" href="/asia/iraq/index.php">
#             Iraq
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            83.2 kg
#           </td>
#           <td>
#            27.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_MUS" href="/africa/mauritius/index.php">
#             Mauritius
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            73.6 kg
#           </td>
#           <td>
#            24.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_EGY" href="/africa/egypt/index.php">
#             Egypt
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            83.1 kg
#           </td>
#           <td>
#            27.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_VEN" href="/america/venezuela/index.php">
#             Venezuela
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            79.8 kg
#           </td>
#           <td>
#            26.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_CHL" href="/america/chile/index.php">
#             Chile
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            82.8 kg
#           </td>
#           <td>
#            27.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_QAT" href="/asia/qatar/index.php">
#             Qatar
#            </a>
#           </td>
#           <td>
#            1.73 m
#           </td>
#           <td>
#            85.7 kg
#           </td>
#           <td>
#            28.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_HTI" href="/america/haiti/index.php">
#             Haiti
#            </a>
#           </td>
#           <td>
#            1.72 m
#           </td>
#           <td>
#            78.0 kg
#           </td>
#           <td>
#            26.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_JPN" href="/asia/japan/index.php">
#             Japan
#            </a>
#           </td>
#           <td>
#            1.72 m
#           </td>
#           <td>
#            69.5 kg
#           </td>
#           <td>
#            23.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_COL" href="/america/colombia/index.php">
#             Colombia
#            </a>
#           </td>
#           <td>
#            1.71 m
#           </td>
#           <td>
#            75.7 kg
#           </td>
#           <td>
#            25.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_THA" href="/asia/thailand/index.php">
#             Thailand
#            </a>
#           </td>
#           <td>
#            1.71 m
#           </td>
#           <td>
#            69.8 kg
#           </td>
#           <td>
#            23.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_TUV" href="/oceania/tuvalu/index.php">
#             Tuvalu
#            </a>
#           </td>
#           <td>
#            1.71 m
#           </td>
#           <td>
#            88.0 kg
#           </td>
#           <td>
#            30.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_CMR" href="/africa/cameroon/index.php">
#             Cameroon
#            </a>
#           </td>
#           <td>
#            1.71 m
#           </td>
#           <td>
#            69.0 kg
#           </td>
#           <td>
#            23.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_SDN" href="/africa/sudan/index.php">
#             Sudan
#            </a>
#           </td>
#           <td>
#            1.71 m
#           </td>
#           <td>
#            67.8 kg
#           </td>
#           <td>
#            23.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_TCD" href="/africa/chad/index.php">
#             Chad
#            </a>
#           </td>
#           <td>
#            1.71 m
#           </td>
#           <td>
#            64.1 kg
#           </td>
#           <td>
#            22.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_PLW" href="/oceania/palau/index.php">
#             Palau
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            86.0 kg
#           </td>
#           <td>
#            29.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_SOM" href="/africa/somalia/index.php">
#             Somalia
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            65.3 kg
#           </td>
#           <td>
#            22.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_ERI" href="/africa/eritrea/index.php">
#             Eritrea
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            58.8 kg
#           </td>
#           <td>
#            20.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_MNG" href="/asia/mongolia/index.php">
#             Mongolia
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            74.7 kg
#           </td>
#           <td>
#            25.8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_SLV" href="/america/el-salvador/index.php">
#             El Salvador
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            77.8 kg
#           </td>
#           <td>
#            26.9
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_SAU" href="/asia/saudi-arabia/index.php">
#             Saudi Arabia
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            80.9 kg
#           </td>
#           <td>
#            28.0
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_MEX" href="/america/mexico/index.php">
#             Mexico
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            79.3 kg
#           </td>
#           <td>
#            27.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_KIR" href="/oceania/kiribati/index.php">
#             Kiribati
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            83.9 kg
#           </td>
#           <td>
#            29.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_ZWE" href="/africa/zimbabwe/index.php">
#             Zimbabwe
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            64.3 kg
#           </td>
#           <td>
#            22.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_KEN" href="/africa/kenya/index.php">
#             Kenya
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            63.9 kg
#           </td>
#           <td>
#            22.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_NGA" href="/africa/nigeria/index.php">
#             Nigeria
#            </a>
#           </td>
#           <td>
#            1.70 m
#           </td>
#           <td>
#            65.1 kg
#           </td>
#           <td>
#            22.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_GHA" href="/africa/ghana/index.php">
#             Ghana
#            </a>
#           </td>
#           <td>
#            1.69 m
#           </td>
#           <td>
#            64.9 kg
#           </td>
#           <td>
#            22.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_NRU" href="/oceania/nauru/index.php">
#             Nauru
#            </a>
#           </td>
#           <td>
#            1.69 m
#           </td>
#           <td>
#            93.0 kg
#           </td>
#           <td>
#            32.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_oz fl_FSM" href="/oceania/micronesia/index.php">
#             Micronesia
#            </a>
#           </td>
#           <td>
#            1.69 m
#           </td>
#           <td>
#            81.1 kg
#           </td>
#           <td>
#            28.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_ZAF" href="/africa/south-africa/index.php">
#             South Africa
#            </a>
#           </td>
#           <td>
#            1.69 m
#           </td>
#           <td>
#            71.9 kg
#           </td>
#           <td>
#            25.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_MYS" href="/asia/malaysia/index.php">
#             Malaysia
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            71.5 kg
#           </td>
#           <td>
#            25.2
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_VNM" href="/asia/vietnam/index.php">
#             Vietnam
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            61.2 kg
#           </td>
#           <td>
#            21.7
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_BOL" href="/america/bolivia/index.php">
#             Bolivia
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            71.2 kg
#           </td>
#           <td>
#            25.3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_AFG" href="/asia/afghanistan/index.php">
#             Afghanistan
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            63.6 kg
#           </td>
#           <td>
#            22.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_COD" href="/africa/congo-kinshasa/index.php">
#             Congo (Dem. Republic)
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            60.2 kg
#           </td>
#           <td>
#            21.4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_ETH" href="/africa/ethiopia/index.php">
#             Ethiopia
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            56.5 kg
#           </td>
#           <td>
#            20.1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_MDV" href="/asia/maldives/index.php">
#             Maldives
#            </a>
#           </td>
#           <td>
#            1.68 m
#           </td>
#           <td>
#            69.2 kg
#           </td>
#           <td>
#            24.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_as fl_LKA" href="/asia/sri-lanka/index.php">
#             Sri Lanka
#            </a>
#           </td>
#           <td>
#            1.67 m
#           </td>
#           <td>
#            63.1 kg
#           </td>
#           <td>
#            22.5
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_am fl_ECU" href="/america/ecuador/index.php">
#             Ecuador
#            </a>
#           </td>
#           <td>
#            1.67 m
#           </td>
#           <td>
#            74.2 kg
#           </td>
#           <td>
#            26.6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="fl_af fl_BDI" href="/africa/burundi/index.php">
#             Burundi
#            </a>
#           </td>
#           <td>
#            1.67 m
#           </td>
#           <td>
#            60.5 kg
# ...
#           73.3 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Central Africa
#          </td>
#          <td>
#           1.69 m
#          </td>
#          <td>
#           62.6 kg
#          </td>
#          <td>
#           1.58 m
#          </td>
#          <td>
#           58.0 kg
#          </td>
#         </tr>
#         <tr class="mtop20">
#          <th>
#          </th>
#          <th colspan="2">
#           <br/>
#           Male
#          </th>
#          <th colspan="2">
#           <br/>
#           Female
#          </th>
#         </tr>
#         <tr>
#          <th class="left">
#           America
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#         </tr>
#         <tr>
#          <td>
#           Caribbean
#          </td>
#          <td>
#           1.74 m
#          </td>
#          <td>
#           78.8 kg
#          </td>
#          <td>
#           1.61 m
#          </td>
#          <td>
#           68.9 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           North America
#          </td>
#          <td>
#           1.77 m
#          </td>
#          <td>
#           90.2 kg
#          </td>
#          <td>
#           1.63 m
#          </td>
#          <td>
#           76.6 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           South America
#          </td>
#          <td>
#           1.73 m
#          </td>
#          <td>
#           79.4 kg
#          </td>
#          <td>
#           1.60 m
#          </td>
#          <td>
#           69.2 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Central America
#          </td>
#          <td>
#           1.69 m
#          </td>
#          <td>
#           77.8 kg
#          </td>
#          <td>
#           1.57 m
#          </td>
#          <td>
#           69.4 kg
#          </td>
#         </tr>
#         <tr class="mtop20">
#          <th>
#          </th>
#          <th colspan="2">
#           <br/>
#           Male
#          </th>
#          <th colspan="2">
#           <br/>
#           Female
#          </th>
#         </tr>
#         <tr>
#          <th class="left">
#           Asia
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#         </tr>
#         <tr>
#          <td>
#           Western Asia
#          </td>
#          <td>
#           1.72 m
#          </td>
#          <td>
#           80.6 kg
#          </td>
#          <td>
#           1.59 m
#          </td>
#          <td>
#           72.2 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           East Asia
#          </td>
#          <td>
#           1.74 m
#          </td>
#          <td>
#           73.3 kg
#          </td>
#          <td>
#           1.62 m
#          </td>
#          <td>
#           61.6 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           South Asia
#          </td>
#          <td>
#           1.66 m
#          </td>
#          <td>
#           60.9 kg
#          </td>
#          <td>
#           1.55 m
#          </td>
#          <td>
#           54.0 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Central Asia
#          </td>
#          <td>
#           1.71 m
#          </td>
#          <td>
#           77.0 kg
#          </td>
#          <td>
#           1.60 m
#          </td>
#          <td>
#           69.2 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Southeast Asia
#          </td>
#          <td>
#           1.67 m
#          </td>
#          <td>
#           62.8 kg
#          </td>
#          <td>
#           1.55 m
#          </td>
#          <td>
#           56.7 kg
#          </td>
#         </tr>
#         <tr class="mtop20">
#          <th>
#          </th>
#          <th colspan="2">
#           <br/>
#           Male
#          </th>
#          <th colspan="2">
#           <br/>
#           Female
#          </th>
#         </tr>
#         <tr>
#          <th class="left">
#           Australia
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#         </tr>
#         <tr>
#          <td>
#           Australia/New Zealand
#          </td>
#          <td>
#           1.78 m
#          </td>
#          <td>
#           88.4 kg
#          </td>
#          <td>
#           1.65 m
#          </td>
#          <td>
#           73.1 kg
#          </td>
#         </tr>
#         <tr class="mtop20">
#          <th>
#          </th>
#          <th colspan="2">
#           <br/>
#           Male
#          </th>
#          <th colspan="2">
#           <br/>
#           Female
#          </th>
#         </tr>
#         <tr>
#          <th class="left">
#           Europe
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#         </tr>
#         <tr>
#          <td>
#           Western Europe
#          </td>
#          <td>
#           1.80 m
#          </td>
#          <td>
#           86.1 kg
#          </td>
#          <td>
#           1.66 m
#          </td>
#          <td>
#           69.2 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Southern Europe
#          </td>
#          <td>
#           1.76 m
#          </td>
#          <td>
#           83.2 kg
#          </td>
#          <td>
#           1.63 m
#          </td>
#          <td>
#           66.9 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Northern Europe
#          </td>
#          <td>
#           1.79 m
#          </td>
#          <td>
#           87.1 kg
#          </td>
#          <td>
#           1.65 m
#          </td>
#          <td>
#           72.3 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Eastern Europe
#          </td>
#          <td>
#           1.78 m
#          </td>
#          <td>
#           83.9 kg
#          </td>
#          <td>
#           1.65 m
#          </td>
#          <td>
#           72.2 kg
#          </td>
#         </tr>
#         <tr class="mtop20">
#          <th>
#          </th>
#          <th colspan="2">
#           <br/>
#           Male
#          </th>
#          <th colspan="2">
#           <br/>
#           Female
#          </th>
#         </tr>
#         <tr>
#          <th class="left">
#           Oceania
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#          <th>
#           Size
#          </th>
#          <th>
#           Weight
#          </th>
#         </tr>
#         <tr>
#          <td>
#           Polynesia
#          </td>
#          <td>
#           1.76 m
#          </td>
#          <td>
#           93.8 kg
#          </td>
#          <td>
#           1.65 m
#          </td>
#          <td>
#           87.3 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Melanesia
#          </td>
#          <td>
#           1.64 m
#          </td>
#          <td>
#           68.1 kg
#          </td>
#          <td>
#           1.57 m
#          </td>
#          <td>
#           64.6 kg
#          </td>
#         </tr>
#         <tr>
#          <td>
#           Micronesia
#          </td>
#          <td>
#           1.69 m
#          </td>
#          <td>
#           82.7 kg
#          </td>
#          <td>
#           1.59 m
#          </td>
#          <td>
#           78.9 kg
#          </td>
#         </tr>
#        </table>
#       </div>
#       <br/>
#       <br/>
#       <h2>
#        Influences on body size
#       </h2>
#       <img alt="Population average" class="mob-img-right" height="320" loading="lazy" src="//cdn.worlddata.info/pics/crowds3.jpg" width="320"/>
#       The main reasons for regional differences in body size are heredity and nutritional standards. Protein-rich food is important, and this is noticeable over generations. Although protein is considered an essential component here, a weakening of the body due to diseases and allergies also has an inhibiting effect on growth. Diseases occur more frequently as a result of weaknesses in the immune system and consume the energy that the body could put into its growth. Good health is primarily due to a good diet, but also a good health system with adequate medical care. As a result, the average body size is remarkably low, especially in poor countries of the third world.
#       <p>
#        Genetic predispositions are another factor for body size. It is not individual genes that speak for or against pronounced growth, but rather the interaction of several dozen genes. Thus, the expressions of these genes are passed on in families or ethnic groups.
#        <br/>
#        <br/>
#        <div class="adtg hrz" data-gptfrmt="hrz" id="adtg-3">
#         <ins class="adsbygoogle" data-ad-client="ca-pub-0315193065476355" data-ad-format="horizontal" data-ad-slot="3247214056" data-full-width-responsive="true" id="ags3">
#         </ins>
#        </div>
#        <h2>
#         Historical increase in size
#        </h2>
#        In almost all countries of the world, the average body size has increased significantly over the last 100 years. While German men were still approximately
#        <span class="metric">
#         13 cm
#        </span>
#        smaller at the beginning of the 20th century, Spanish men increased over
#        <span class="metric">
#         14 cm
#        </span>
#        and Iranians over
#        <span class="metric">
#         16 cm
#        </span>
#        . With the women, the height of South-Korean-women rose by over
#        <span class="metric">
#         20 cm
#        </span>
#        .
#        <p>
#         These drastic increases are unique in the history of human beings. In no phase of evolution have human beings become so much bigger as since the industrial revolution at the end of the 18th century. In the preceding 1,000 years, both men and women did not grow at all on average and before that only by 1-2 cm per 1,000 years.
#         <div class="br3">
#         </div>
#         Strikingly often, an
#         <a href="/average-penissize.php">
#          international comparison of penis sizes
#         </a>
#         is requested here, which is now available on a separate page. Additionally an evaluation of the
#         <a href="/average-breastsize.php">
#          average cup sizes
#         </a>
#         by country now exists.
#         <h2>
#          Data sources
#         </h2>
#         All data for sizes and weights are based on a summary of scientific studies evaluated and published by the
#         <a href="https://www.ncdrisc.org/index.html" rel="noopener" target="_blank">
#          NCD Risk Factor Collaboration
#         </a>
#         (NCD-RisC). The more than 1,200 studies summarized there are from the analysis of the year 2020. A summary of more than 2,100 studies from the years 1985 to 2019 can also be found in the medical journal
#         <a href="https://www.thelancet.com/journals/lancet/article/PIIS0140-6736(20)31859-6/fulltext" rel="noopener" target="_blank">
#          The Lancet
#         </a>
#         .
#         <br/>
#         <br/>
#        </p>
#       </p>
#      </div>
#      <script>
#       var d=document;let bigscreen=window.matchMedia("(min-width:850px)"); toggleTab(bigscreen); function toggleTab(bigscreen){ if(bigscreen.matches){ xhttp=new XMLHttpRequest(); xhttp.onreadystatechange=function(){ if(xhttp.readyState==4&&xhttp.status==200){ d.getElementById('averageheights').innerHTML=xhttp.responseText; var script=d.createElement('script'); d.getElementsByTagName("head")[0].appendChild(script); script.src='//cdn.worlddata.info/js/tablesort.min.js'; script.onload=function(){ if(typeof initlinks==='function'){initlinks();} new Tablesort(d.getElementById('avgsizes')); }; } }; xhttp.open("GET","/average-heights-en.txt",true);xhttp.send(); } } function toggleMetrics(to){ var cells=d.querySelectorAll('table.std100 tr td,.metric'),mtgl=d.getElementById('metricToggler'); for (c=0;c<cells.length;c++){cm=false;kg=false; if(cells[c].dataset.cm>0){cm=parseInt(cells[c].dataset.cm);} if(cells[c].dataset.kg>0){kg=parseFloat(cells[c].dataset.kg);} else if(cells[c].textContent.match(/^(\d\.\d+) m$/gi)){cm=parseFloat(RegExp.$1)*100;cells[c].dataset.cm=cm;} else if(cells[c].textContent.match(/^(\d+) cm$/gi)){cm=parseFloat(RegExp.$1);cells[c].dataset.cm=cm;} if(cells[c].textContent.match(/^(\d+\.\d+) kg$/gi)){kg=parseFloat(RegExp.$1);cells[c].dataset.kg=kg;} if(cm&&to=='us'){cells[c].innerHTML=cm2ft(cm);} else if(cm){cells[c].innerHTML=(cm/100).toString().padEnd(4,'0')+' m';} else if(kg&&to=='us'){cells[c].innerHTML=Math.round(kg*22.05)/10+' lb';} else if(kg){cells[c].innerHTML=kg+' kg';} } if(to=='us'){mtgl.innerHTML='<a href="#" onclick="return toggleMetrics('+"'int'"+');">Convert units to meters and kilograms.</a>';} else{mtgl.innerHTML='<a href="#" onclick="return toggleMetrics('+"'us'"+');">Convert units to feet and pounds.</a>';} return false; } function cm2ft(cm){ ft=Math.floor(cm/30.48);rest=cm-(30.48*ft);inch=Math.floor(rest/2.54);rest=(rest-(2.54*inch))/2.54;if(ft!=0){ft=ft+"' ";} if(rest<0.063){return ft+inch+'"';} else if(rest<0.063+0.125){return ft+inch+'&frac18;"';} else if(rest<0.063+0.250){return ft+inch+'&frac14;"';} else if(rest<0.063+0.375){return ft+inch+'&frac38;"';} else if(rest<0.063+0.500){return ft+inch+'&frac12;"';} else if(rest<0.063+0.625){return ft+inch+'&frac58;"';} else if(rest<0.063+0.750){return ft+inch+'&frac34;"';} else if(rest<0.063+0.875){return ft+inch+'&frac78;"';} else{return ft+Math.round(inch+1)+'"';} }
#      </script>
#     </main>
#     <footer id="footer">
#      <div id="socials">
#      </div>
#      <div class="breadcrumbs">
#       You are here:
#       <a href="/">
#        Home
#       </a>
#       ›
#       <span style="color:#00FFFF;">
#        Average sizes
#       </span>
#      </div>
#      <script type="application/ld+json">
#       {"@context": "https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Homepage","item":"https://www.worlddata.info/"},{"@type":"ListItem","position":2,"name":"Average sizes","item":"https://www.worlddata.info/average-bodyheight.php"}]}
#      </script>
#      <a href="/quiz/">
#       Country Quiz
#      </a>
#      <a href="/countrycodes.php">
#       Country codes
#      </a>
#      <a href="/downloads/">
#       CSV downloads
#      </a>
#      <a href="/definition-country.php">
#       What is a country?
#      </a>
#      <div id="searchform">
#       <form action="/search.php" method="get">
#        <input aria-label="search term" autocomplete="off" id="searcht" name="q" placeholder="search" type="text" value=""/>
#        <button aria-label="start search" data-lazybg="/pics/search.png" id="searchgo">
#        </button>
#       </form>
#       <a class="langh" href="https://www.laenderdaten.info/durchschnittliche-koerpergroessen.php" hreflang="de" lang="de" rel="alternate" style="background-position:2px 1px;" title="Comparison: Average height worldwide">
#        deutsch
#       </a>
#       <a class="langh" href="https://www.datosmundial.com/estatura-promedio.php" hreflang="es" lang="es" rel="alternate" style="background-position:-348px 1px;" title="Comparación: valores medios en todo el mundo">
#        español
#       </a>
#       <a class="langh" href="https://www.dadosmundiais.com/altura-media.php" hreflang="pt" id="lngpt" lang="pt" rel="alternate" style="background-position:-1028px 1px;" title="Comparação: Alturas médias em todo o mundo">
#        português
#       </a>
#       <a class="langh" href="https://www.donneesmondiales.com/taille-moyenne.php" hreflang="fr" lang="fr" rel="alternate" style="background-position:-518px 1px;" title="Comparaison : tailles moyennes dans le monde">
#        français
#       </a>
#      </div>
#      <br/>
#      <br/>
#      <a class="legal" href="/about.php">
#       About worlddata.info
#      </a>
#      <a class="legal" href="/privacypolicy.php">
#       Privacy policy
#      </a>
#      <a class="legal" href="/cookieconsent2.php" onclick="return openCookieconsent(1);" rel="nofollow">
#       Cookie settings
#      </a>
#      <a class="legal" href="/report-an-error.php" id="errep">
#       Report an error
#      </a>
#      <br/>
#      <br/>
#      Data without guarantee © WorldData.info, all rights reserved
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %%
import pandas as pd
def crawl_stats(url):
    response = requests.get(url)

    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch the page. Status code: {response.status_code}")
        return None

url = "https://www.worlddata.info/average-bodyheight.php"
html_content = crawl_stats(url)

if html_content:
    soup = BeautifulSoup(html_content, 'html.parser')
    table = soup.find('div', id='averageheights')

    data = []
    if table:
        rows = table.find_all('tr')

        for row in rows[1:]:
            cells = row.find_all('td')

            # Check if there are at least 4 cells in the row (including country link)
            if len(cells) >= 4:
                country = cells[0].text.strip()
                height = cells[1].text.strip()
                weight = cells[2].text.strip()
                bmi = cells[3].text.strip()

                data.append([country, height, weight, bmi])

        # Create DataFrame
        columns = ['Country', 'Average height', 'Weight', 'BMI']
        df = pd.DataFrame(data, columns=columns)
        print(df)
else:
    print("Failed to fetch the page.")
# Out:
#                     Country Average height   Weight   BMI
# 0               Netherlands         1.84 m  87.9 kg  26.1
# 1                Montenegro         1.83 m  90.4 kg  27.0
# 2                   Estonia         1.82 m  89.9 kg  27.0
# 3                   Denmark         1.82 m  86.8 kg  26.3
# 4    Bosnia and Herzegovina         1.82 m  87.1 kg  26.4
# ..                      ...            ...      ...   ...
# 245              Madagascar         1.53 m  49.2 kg  21.1
# 246              Bangladesh         1.52 m  50.5 kg  21.8
# 247                   Nepal         1.52 m  51.6 kg  22.3
# 248             Timor-Leste         1.52 m  49.0 kg  21.2
# 249               Guatemala         1.51 m  61.9 kg  27.3
#
# [250 rows x 4 columns]

# %%
dfmen = df.iloc[0:125]
dfwomen = df.iloc[125:250]

# %%
dfmen = dfmen.rename(columns={'Average height': 'Average height men'})
dfmen = dfmen.rename(columns={'Weight': 'Weight men'})
dfmen = dfmen.rename(columns={'BMI': 'BMI men'})
dfmen
# Out:
#                     Country Average height men Weight men BMI men
# 0               Netherlands             1.84 m    87.9 kg    26.1
# 1                Montenegro             1.83 m    90.4 kg    27.0
# 2                   Estonia             1.82 m    89.9 kg    27.0
# 3                   Denmark             1.82 m    86.8 kg    26.3
# 4    Bosnia and Herzegovina             1.82 m    87.1 kg    26.4
# ..                      ...                ...        ...     ...
# 120                   Nepal             1.64 m    60.5 kg    22.5
# 121               Guatemala             1.64 m    69.1 kg    25.7
# 122                   Yemen             1.63 m    62.5 kg    23.6
# 123                    Laos             1.62 m    59.5 kg    22.6
# 124             Timor-Leste             1.59 m    53.9 kg    21.2
#
# [125 rows x 4 columns]

# %%
dfwomen = dfwomen.rename(columns={'Average height': 'Average height women'})
dfwomen = dfwomen.rename(columns={'Weight': 'Weight women'})
dfwomen = dfwomen.rename(columns={'BMI': 'BMI women'})
dfwomen
# Out:
#          Country Average height women Weight women BMI women
# 125  Netherlands               1.70 m      73.2 kg      25.3
# 126   Montenegro               1.70 m      75.3 kg      26.2
# 127      Denmark               1.69 m      70.2 kg      24.6
# 128      Iceland               1.68 m      72.6 kg      25.6
# 129      Estonia               1.68 m      73.7 kg      26.0
# ..           ...                  ...          ...       ...
# 245   Madagascar               1.53 m      49.2 kg      21.1
# 246   Bangladesh               1.52 m      50.5 kg      21.8
# 247        Nepal               1.52 m      51.6 kg      22.3
# 248  Timor-Leste               1.52 m      49.0 kg      21.2
# 249    Guatemala               1.51 m      61.9 kg      27.3
#
# [125 rows x 4 columns]

# %%
csv_file = "R_population_characteristics_men.csv"
dfmen.to_csv(csv_file, index=False, encoding='utf-8')
print(f"DataFrame saved to {csv_file}")
        
csv_file = "R_population_characteristics_women.csv"
dfwomen.to_csv(csv_file, index=False, encoding='utf-8')
print(f"DataFrame saved to {csv_file}")
# Out:
# DataFrame saved to R_population_characteristics_men.csv
# DataFrame saved to R_population_characteristics_women.csv
